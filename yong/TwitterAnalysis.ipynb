# %% [markdown]
# <h1><center>Twitter Analysis</center></h1>

# %% [markdown]
# <h2>Import packages</h2>

# %%
import re
from textblob import TextBlob
from pyspark.sql.functions import udf, when, substring, col, lit, size
from pyecharts import Bar, Pie, WordCloud, Map, Liquid
from geopy.geocoders import Nominatim
import pandas as pd

# %% [markdown]
# <h2>Define input path and load data</h2>

# %%
# Specify input data path
INPUT_FILE_PATH = '/home/yong/Desktop/CS5590_Spark_Project/yong/data.json'
# Read data with Spark
data_df = spark.read.json(INPUT_FILE_PATH)

# %% [markdown]
# <h2 style="color:blue">
# <center>
# Query 1: Find polarity percentage for tweets' text field
# </center>
# </h2>

# %%
# Revemove the special characters in the tweet
def clean_tweet(tweet):
    return ' '.join(re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', tweet).split())

# Calculate the polarity of the tweet
def get_polarity(tweet):
    return TextBlob(clean_tweet(tweet)).sentiment.polarity

# Create UDF for calculating polarity
get_polarity_udf = udf(get_polarity)

# %%
# Create temp view for polarities
data_df.select(get_polarity_udf('text').alias('polarity')).createOrReplaceTempView('polarities')

# Calculate percentage for polarity
polarity_df = spark.sql('''
    SELECT
        SUM(CASE WHEN CAST(polarity AS FLOAT) > 0 THEN 1 ELSE 0 END) / COUNT(*) * 100 AS positive,
        SUM(CASE WHEN CAST(polarity AS FLOAT) < 0 THEN 1 ELSE 0 END) / COUNT(*) * 100 AS negative,
        SUM(CASE WHEN CAST(polarity AS FLOAT) = 0 THEN 1 ELSE 0 END) / COUNT(*) * 100 AS neutral
    FROM
        polarities
''')
# Convert into pandas dataframe
polarity_pd = polarity_df.toPandas()

# %%
# Render graph
attr = polarity_pd.columns.values
values = polarity_pd.values[0]
pie = Pie('Polarity Percentage')
pie.add('Percentage', attr, values, is_label_show=True)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5a7675784ef8481594ffb6a75d0a6de3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5a7675784ef8481594ffb6a75d0a6de3 = echarts.init(document.getElementById('5a7675784ef8481594ffb6a75d0a6de3'), 'light', {renderer: 'canvas'});
#
# var option_5a7675784ef8481594ffb6a75d0a6de3 = {
#     "animation": true,
#     "series": [
#         {
#             "data": [
#                 {
#                     "name": "positive",
#                     "value": 39.717
#                 },
#                 {
#                     "name": "negative",
#                     "value": 22.678
#                 },
#                 {
#                     "name": "neutral",
#                     "value": 37.605
#                 }
#             ],
#             "name": "Percentage",
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%",
#                     "position": "outside"
#                 }
#             },
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "type": "pie",
#             "seriesId": 7687715,
#             "center": [
#                 "50%",
#                 "50%"
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "left": "center",
#             "data": [
#                 "positive",
#                 "negative",
#                 "neutral"
#             ],
#             "show": true,
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "tooltip": {
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "borderColor": "#333"
#     },
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto",
#             "text": "Polarity Percentage",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto"
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         },
#         "top": "center"
#     },
#     "series_id": 7687715
# };
# myChart_5a7675784ef8481594ffb6a75d0a6de3.setOption(option_5a7675784ef8481594ffb6a75d0a6de3);
#
#     });
# </script>

# %% [markdown]
# <h2 style="color:blue">
# <center>
# Query 2: Find the created year distribution for users
# </center>
# </h2>

# %%
# Create temp view for user_created_year
data_df.select(
    'user.id',
    substring('user.created_at', -4, 4).alias('year')
).distinct().createOrReplaceTempView('user_created_year')

# Get count for each year from distinct users
created_year_df = spark.sql('''
    SELECT
        year,
        COUNT(*) AS count
    FROM
        user_created_year
    GROUP BY
        year
    ORDER BY
        year DESC
''')

# Convert into pandas dataframe
created_year_pd = created_year_df.toPandas()

# %%
# Render graph
created_year_bar = Bar('Created year distribution')
attr = created_year_pd.values[:,0]
values = created_year_pd.values[:,1]
created_year_bar.add('Count', attr, values, mark_point=['max', 'min'])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2db67896c76c4891abc1c36298d40598" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2db67896c76c4891abc1c36298d40598 = echarts.init(document.getElementById('2db67896c76c4891abc1c36298d40598'), 'light', {renderer: 'canvas'});
#
# var option_2db67896c76c4891abc1c36298d40598 = {
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         },
#         "top": "center"
#     },
#     "animation": true,
#     "series": [
#         {
#             "data": [
#                 7849.0,
#                 8444.0,
#                 7372.0,
#                 5771.0,
#                 5738.0,
#                 6233.0,
#                 7682.0,
#                 7455.0,
#                 5064.0,
#                 9537.0,
#                 2245.0,
#                 397.0,
#                 22.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false,
#                     "position": "top"
#                 }
#             },
#             "name": "Count",
#             "type": "bar",
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "symbol": "pin",
#                         "type": "max",
#                         "symbolSize": 50,
#                         "name": "Maximum",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "symbol": "pin",
#                         "type": "min",
#                         "symbolSize": 50,
#                         "name": "Minimum",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "seriesId": 2335783
#         }
#     ],
#     "legend": [
#         {
#             "left": "center",
#             "data": [
#                 "Count"
#             ],
#             "show": true,
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "tooltip": {
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "borderColor": "#333"
#     },
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto",
#             "text": "Created year distribution",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto"
#         }
#     ],
#     "xAxis": [
#         {
#             "nameGap": 25,
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8
#             },
#             "boundaryGap": true,
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "show": true,
#             "data": [
#                 2018.0,
#                 2017.0,
#                 2016.0,
#                 2015.0,
#                 2014.0,
#                 2013.0,
#                 2012.0,
#                 2011.0,
#                 2010.0,
#                 2009.0,
#                 2008.0,
#                 2007.0,
#                 2006.0
#             ],
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "type": "category"
#         }
#     ],
#     "series_id": 2335783,
#     "yAxis": [
#         {
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "show": true,
#             "nameGap": 25,
#             "boundaryGap": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "margin": 8
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "type": "value",
#             "nameLocation": "middle",
#             "inverse": false
#         }
#     ]
# };
# myChart_2db67896c76c4891abc1c36298d40598.setOption(option_2db67896c76c4891abc1c36298d40598);
#
#     });
# </script>

# %% [markdown]
# <h2 style="color:blue">
# <center>
# Query 3: Find most popular login sources
# </center>
# </h2>

# %%
# Create temp view for user_login_source
data_df.select(
    'user.id',
    'source'
).distinct().createOrReplaceTempView('user_login_source')

# Get count for top 10 login source type
user_login_source_df = spark.sql('''
    SELECT
        source,
        COUNT(*) AS count
    FROM (
        SELECT
            SUBSTR(
                source,
                LOCATE('>', source) + 1,
                LOCATE('<', SUBSTR(source, LOCATE('>', source))) -2
            ) AS source
        FROM
            user_login_source
    ) t1
    GROUP BY
        source
    ORDER BY
        count DESC
    LIMIT 5
''')

# Convert into pandas dataframe
user_login_source_pd = user_login_source_df.toPandas()

# %%
# Render graph
user_login_source_bar = Bar('Login source distribution')
attr = user_login_source_pd.values[:,0]
values = user_login_source_pd.values[:,1]
user_login_source_bar.add('Count', attr, values, mark_line=["average"])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b521d5b7a81c484a8740d9de83824dab" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b521d5b7a81c484a8740d9de83824dab = echarts.init(document.getElementById('b521d5b7a81c484a8740d9de83824dab'), 'light', {renderer: 'canvas'});
#
# var option_b521d5b7a81c484a8740d9de83824dab = {
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         },
#         "top": "center"
#     },
#     "animation": true,
#     "series": [
#         {
#             "data": [
#                 33304.0,
#                 18220.0,
#                 10407.0,
#                 3847.0,
#                 3500.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false,
#                     "position": "top"
#                 }
#             },
#             "name": "Count",
#             "type": "bar",
#             "markLine": {
#                 "symbolSize": 10,
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ]
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "seriesId": 1744428
#         }
#     ],
#     "legend": [
#         {
#             "left": "center",
#             "data": [
#                 "Count"
#             ],
#             "show": true,
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "tooltip": {
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "borderColor": "#333"
#     },
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto",
#             "text": "Login source distribution",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto"
#         }
#     ],
#     "xAxis": [
#         {
#             "nameGap": 25,
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8
#             },
#             "boundaryGap": true,
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "show": true,
#             "data": [
#                 "Twitter for iPhone",
#                 "Twitter for Android",
#                 "Twitter Web Client",
#                 "Twitter for iPad",
#                 "Twitter Lite"
#             ],
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "type": "category"
#         }
#     ],
#     "series_id": 1744428,
#     "yAxis": [
#         {
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "show": true,
#             "nameGap": 25,
#             "boundaryGap": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "margin": 8
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "type": "value",
#             "nameLocation": "middle",
#             "inverse": false
#         }
#     ]
# };
# myChart_b521d5b7a81c484a8740d9de83824dab.setOption(option_b521d5b7a81c484a8740d9de83824dab);
#
#     });
# </script>

# %% [markdown]
# <h2 style="color:blue">
# <center>
# Query 4: Generate word cloud for hashtags' popularity
# </center>
# </h2>

# %%
# Create temp view for hashtags
data_df.select('entities.hashtags.text').createOrReplaceTempView('hashtags')

# Get count for each hashtag
hashtags_df = spark.sql('''
    SELECT
        LOWER(text) as text,
        COUNT(*) AS count
    FROM (
        SELECT
            EXPLODE(text) AS text
        FROM
            hashtags
    ) t1
    GROUP by
        LOWER(text)
    ORDER BY
        count DESC
''')

# Convert into pandas dataframe
hashtags_pd = hashtags_df.toPandas()

# %%
# Render graph
wordcloud = WordCloud(width=800, height=600)
attr = hashtags_pd.values[:,0]
values = hashtags_pd.values[:,1]
wordcloud.add("", attr, values)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="7a846c70b5c34648972ee637e0614515" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_7a846c70b5c34648972ee637e0614515 = echarts.init(document.getElementById('7a846c70b5c34648972ee637e0614515'), 'light', {renderer: 'canvas'});
#
# var option_7a846c70b5c34648972ee637e0614515 = {
#     "animation": true,
#     "series": [
#         {
#             "rotationStep": 45,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(12,34,107)"
#                         }
#                     },
#                     "name": "halloween",
#                     "value": 766
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(54,68,55)"
#                         }
#                     },
#                     "name": "dennismilleroption",
#                     "value": 441
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(119,150,72)"
#                         }
#                     },
#                     "name": "happyhalloween",
#                     "value": 422
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,79,33)"
#                         }
#                     },
#                     "name": "cat",
#                     "value": 389
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,95,46)"
#                         }
#                     },
#                     "name": "dog",
#                     "value": 358
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,110,83)"
#                         }
#                     },
#                     "name": "dogs",
#                     "value": 227
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,42,81)"
#                         }
#                     },
#                     "name": "vote",
#                     "value": 202
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,26,103)"
#                         }
#                     },
#                     "name": "votegop",
#                     "value": 202
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,113,148)"
#                         }
#                     },
#                     "name": "breaking",
#                     "value": 198
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,100,5)"
#                         }
#                     },
#                     "name": "cats",
#                     "value": 197
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,66,98)"
#                         }
#                     },
#                     "name": "florida",
#                     "value": 194
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,9,116)"
#                         }
#                     },
#                     "name": "animallovers",
#                     "value": 186
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,43,57)"
#                         }
#                     },
#                     "name": "catsoftwitter",
#                     "value": 167
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(61,10,125)"
#                         }
#                     },
#                     "name": "kitten",
#                     "value": 156
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,142,5)"
#                         }
#                     },
#                     "name": "cute",
#                     "value": 151
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,34,85)"
#                         }
#                     },
#                     "name": "love",
#                     "value": 142
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,83,92)"
#                         }
#                     },
#                     "name": "python",
#                     "value": 135
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,74,5)"
#                         }
#                     },
#                     "name": "halloween2018",
#                     "value": 135
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,108,4)"
#                         }
#                     },
#                     "name": "catsarefamily",
#                     "value": 117
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(7,10,85)"
#                         }
#                     },
#                     "name": "catsarelove",
#                     "value": 115
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,137,96)"
#                         }
#                     },
#                     "name": "aldub172ndweeksary",
#                     "value": 115
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(27,107,12)"
#                         }
#                     },
#                     "name": "trump",
#                     "value": 110
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(64,143,58)"
#                         }
#                     },
#                     "name": "dogsoftwitter",
#                     "value": 110
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,72,93)"
#                         }
#                     },
#                     "name": "fbrparty",
#                     "value": 103
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(151,5,123)"
#                         }
#                     },
#                     "name": "trickortreat",
#                     "value": 98
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,26,30)"

# %% [markdown]
# <h2 style="color:blue">
# <center>
# Query 5: Count null and not null for geo tag
# </center>
# </h2>

# %%
# Create temp view for geo_location
data_df.select('geo').createOrReplaceTempView('geo_location')

# Get count for total number of tweets with geo info
geo_df = spark.sql('''
    SELECT
        SUM(CASE WHEN geo IS NULL THEN 1 ELSE 0 END) AS count_nulls,
        COUNT(geo) AS count_not_nulls
    FROM
        geo_location
''')

# Convert into pandas dataframe
geo_pd = geo_df.toPandas()

# %%
# Render graph
attr = geo_pd.columns
values = geo_pd.values[0]
pie = Pie('Count Null and Not Null for Geo')
pie.add('Count', geo_pd.columns, values, is_label_show=True)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="67f3335d47dd49c3990dc08d74354633" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_67f3335d47dd49c3990dc08d74354633 = echarts.init(document.getElementById('67f3335d47dd49c3990dc08d74354633'), 'light', {renderer: 'canvas'});
#
# var option_67f3335d47dd49c3990dc08d74354633 = {
#     "animation": true,
#     "series": [
#         {
#             "data": [
#                 {
#                     "name": "count_nulls",
#                     "value": 99854.0
#                 },
#                 {
#                     "name": "count_not_nulls",
#                     "value": 146.0
#                 }
#             ],
#             "name": "Count",
#             "label": {
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 },
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%",
#                     "position": "outside"
#                 }
#             },
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "type": "pie",
#             "seriesId": 7947554,
#             "center": [
#                 "50%",
#                 "50%"
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "left": "center",
#             "data": [
#                 "count_nulls",
#                 "count_not_nulls"
#             ],
#             "show": true,
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "tooltip": {
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "borderColor": "#333"
#     },
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto",
#             "text": "Count Null and Not Null for Geo",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto"
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         },
#         "top": "center"
#     },
#     "series_id": 7947554
# };
# myChart_67f3335d47dd49c3990dc08d74354633.setOption(option_67f3335d47dd49c3990dc08d74354633);
#
#     });
# </script>

# %% [markdown]
# <h2 style="color:blue">
# <center>
# Query 6: Get country code distribution from geo tag
# </center>
# </h2>

# %%
# Create a geo locator
# With geo, we can get the extrat location of the user who sent the tweets
geolocator = Nominatim(user_agent="Twitter Analysis")

# %%
# Get all geo that are not null
coordinates_df = spark.sql('''
    SELECT
        geo.coordinates
    FROM
        geo_location
    WHERE
        geo IS NOT NULL
''')

# %%
# Create a function to reverse coordinates to country code
def get_geo_country(coordinates):
    return geolocator.reverse(str(coordinates[0]) + ", " + str(coordinates[1])).raw['address']['country']

# %%
# Convert coordinates_df into pandas dataframe then into Python list
coordinates = list(coordinates_df.toPandas().coordinates)

# %%
country_code_dict = dict()
for _ in coordinates:
    country_code = get_geo_country(_)
    if country_code in country_code_dict:
        country_code_dict[country_code] = country_code_dict[country_code] + 1
    else:
        country_code_dict[country_code] = 1

# %%
country_code_df = pd.DataFrame.from_dict(country_code_dict, orient='index',columns=['Count'])

# %%
country_code_df.sort_values(by='Count', ascending=False)
# Out:
#                       Count
# USA                     119
# Canada                   11
# New Zealand/Aotearoa      3
# UK                        3
# Brasil                    2
# Philippines               2
# ประเทศไทย                 1
# Chile                     1
# Ireland                   1
# Australia                 1
# 대한민국                      1
# India                     1

# %% [markdown]
# <h2 style="color:blue">
# <center>
# Query 7: Get top 10 country codes distribution from place tag
# </center>
# </h2>

# %%
data_df.select('place').createOrReplaceTempView('places')

# %%
spark.sql('''
    SELECT
        place.country_code,
        count(*) AS count
    FROM
        places
    WHERE
        place IS NOT NULL
    GROUP BY
        place.country_code
    ORDER BY
        2 desc
    LIMIT 10
''').show()
# Out:
# +------------+-----+
# |country_code|count|
# +------------+-----+
# |          US| 1147|
# |          CA|   49|
# |          GB|   47|
# |          AU|   17|
# |          PH|   10|
# |          BR|    6|
# |          IN|    6|
# |          JP|    5|
# |          NZ|    4|
# |          MY|    4|
# +------------+-----+

# %% [markdown]
# <h2 style="color:blue">
# <center>
# Query 8: Message truncated percentage
# </center>
# </h2>

# %%
data_df.select('truncated').createOrReplaceTempView('tweet_truncated')

# %%
# Create a dataframe to calculte the message truncated percentage
truncated_percentage_df = spark.sql('''
    SELECT
        truncated,
        COUNT(*) / (SELECT COUNT(*) FROM tweet_truncated) AS percentage
    FROM
        tweet_truncated
    GROUP BY 
        truncated
''')

# Convert into pandas dataframe
truncated_percentage_pd = truncated_percentage_df.toPandas()

# %%
# Render graph
liquid = Liquid("Message truncated percentage")
liquid.add("Liquid", [truncated_percentage_pd.query('truncated == True').percentage])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min'
#         }
#     });
# </script>
#     <div id="fc6deb191c7e4027bf7a1e7ec4f1319e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'liquidfill'], function(echarts) {
#
# var myChart_fc6deb191c7e4027bf7a1e7ec4f1319e = echarts.init(document.getElementById('fc6deb191c7e4027bf7a1e7ec4f1319e'), 'light', {renderer: 'canvas'});
#
# var option_fc6deb191c7e4027bf7a1e7ec4f1319e = {
#     "animation": true,
#     "series": [
#         {
#             "waveAnimation": true,
#             "outline": {
#                 "show": true
#             },
#             "data": [
#                 [
#                     0.09193
#                 ]
#             ],
#             "name": "Liquid",
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "type": "liquidFill",
#             "animationDuration": 2000,
#             "shape": "circle",
#             "animationDurationUpdate": 1000
#         }
#     ],
#     "legend": [
#         {
#             "left": "center",
#             "data": [],
#             "show": true,
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "tooltip": {
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "borderColor": "#333"
#     },
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto",
#             "text": "Message truncated percentage",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto"
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         },
#         "top": "center"
#     },
#     "series_id": 104823
# };
# myChart_fc6deb191c7e4027bf7a1e7ec4f1319e.setOption(option_fc6deb191c7e4027bf7a1e7ec4f1319e);
#
#     });
# </script>

# %% [markdown]
# <h2 style="color:blue">
# <center>
# Query 9: User verified distribution and analysis
# </center>
# </h2>

# %%
# Check how many users have verified account
data_df.groupBy('user.verified').count().show()
# Out:
# +--------+-----+
# |verified|count|
# +--------+-----+
# |    true| 1221|
# |   false|98779|
# +--------+-----+

# %%
data_df.select('user.verified', 'user.default_profile').createOrReplaceTempView('verified_users_profile')

# %%
# Check how many verified users are/are not using default profile
spark.sql('''
    SELECT
        default_profile,
        COUNT(*) AS count
    FROM
        verified_users_profile
    WHERE
        verified = 'true'
    GROUP BY
        default_profile
''').show()
# Out:
# +---------------+-----+
# |default_profile|count|
# +---------------+-----+
# |           true|  218|
# |          false| 1003|
# +---------------+-----+

# %%
# Check how many un-verified users are/are not using default profile
spark.sql('''
    SELECT
        default_profile,
        COUNT(*) AS count
    FROM
        verified_users_profile
    WHERE
        verified = 'false'
    GROUP BY
        default_profile
''').show()
# Out:
# +---------------+-----+
# |default_profile|count|
# +---------------+-----+
# |           true|55598|
# |          false|43181|
# +---------------+-----+

# %% [markdown]
# <h2 style="color:blue">
# <center>
# Query 10: Analysis on friends_count and followers_count
# </center>
# </h2>

# %%
# Users count where the number of friends_count is greater than followers_count
data_df.where('user.friends_count > user.followers_count').count()
# Out:
# 61730

# %%
# Users count where the number of friends_count is less than followers_count
data_df.where('user.friends_count < user.followers_count').count()
# Out:
# 37952

# %%
# Users count where the number of friends_count is the same as followers_count
data_df.where('user.friends_count = user.followers_count').count()
# Out:
# 318

# %% [markdown]
# <h2 style="color:blue">
# <center>
# Machine Learning: Frequent Pattern Mining
# </center>
# </h2>

# %%
from pyspark.ml.fpm import FPGrowth

# %%
# Generate computed columns for geo_enabled, profile_background_tile, profile_use_background_image,
# and default_profile and save the result to a list
data_list = data_df.select(
    when(data_df.truncated == "true", 1).otherwise(0).alias("truncated"),
    when(data_df.user.verified == "true", 1).otherwise(0).alias("verified"),
    when(data_df.user.geo_enabled == "true", 1).otherwise(0).alias("geo_enabled"),
    when(data_df.user.profile_background_tile == "true", 1).otherwise(0).alias("profile_background_tile"),
    when(data_df.user.profile_use_background_image == "true", 1).otherwise(0).alias("profile_use_background_image"),
    when(data_df.user.default_profile == "true", 1).otherwise(0).alias("default_profile")
).collect()

# %%
# Generate new data list for ML
ml_data_list = []
index = 0

for row in data_list:
    temp_data_list = []
    if row[0] == 1:
        temp_data_list.append('truncated')
    if row[1] == 1:
        temp_data_list.append('verified')
    if row[2] == 1:
        temp_data_list.append('geo_enabled')
    if row[3] == 1:
        temp_data_list.append('profile_background_tile')
    if row[4] == 1:
        temp_data_list.append('profile_use_background_image')
    if row[5] == 1:
        temp_data_list.append('default_profile')
    if temp_data_list:
        ml_data_list.append((index, temp_data_list))
        index += 1

# %%
# Generate analysis dataframe
analysis_df = spark.createDataFrame(ml_data_list, ['id', 'items'])

# %%
# Create the model and fit the dataframe into the model
fp_growth = FPGrowth(itemsCol="items", minSupport=0.50, minConfidence=0.6)
model = fpGrowth.fit(analysis_df)

# %%
# Display frequent itemsets
model.freqItemsets.show(truncate=False)
# Out:
# +-----------------------------------------------+-----+
# |items                                          |freq |
# +-----------------------------------------------+-----+
# |[profile_use_background_image]                 |80317|
# |[default_profile]                              |55816|
# |[default_profile, profile_use_background_image]|55816|
# +-----------------------------------------------+-----+

# %%
# Display generated association rules
model.associationRules.show(truncate=False)
# Out:
# +------------------------------+------------------------------+------------------+
# |antecedent                    |consequent                    |confidence        |
# +------------------------------+------------------------------+------------------+
# |[default_profile]             |[profile_use_background_image]|1.0               |
# |[profile_use_background_image]|[default_profile]             |0.6949462753837917|
# +------------------------------+------------------------------+------------------+

# %%
# Show distinct prediction count
model.transform(analysis_df).groupBy("prediction").count().show()
# Out:
# +-----------------+-----+
# |       prediction|count|
# +-----------------+-----+
# |               []|64601|
# |[default_profile]|24501|
# +-----------------+-----+

# %%
# Display prediction
model.transform(analysis_df).show(tdruncate=False)
# Out:
# +---+-----------------------------------------------------------------------+-----------------+
# |id |items                                                                  |prediction       |
# +---+-----------------------------------------------------------------------+-----------------+
# |0  |[profile_use_background_image, default_profile]                        |[]               |
# |1  |[geo_enabled, profile_use_background_image, default_profile]           |[]               |
# |2  |[profile_use_background_image]                                         |[default_profile]|
# |3  |[truncated, profile_use_background_image, default_profile]             |[]               |
# |4  |[profile_use_background_image, default_profile]                        |[]               |
# |5  |[profile_use_background_image, default_profile]                        |[]               |
# |6  |[profile_use_background_image, default_profile]                        |[]               |
# |7  |[geo_enabled, profile_use_background_image]                            |[default_profile]|
# |8  |[geo_enabled, profile_use_background_image, default_profile]           |[]               |
# |9  |[profile_use_background_image, default_profile]                        |[]               |
# |10 |[profile_use_background_image, default_profile]                        |[]               |
# |11 |[truncated, geo_enabled, profile_use_background_image, default_profile]|[]               |
# |12 |[truncated, profile_use_background_image]                              |[default_profile]|
# |13 |[geo_enabled, profile_background_tile, profile_use_background_image]   |[default_profile]|
# |14 |[profile_use_background_image, default_profile]                        |[]               |
# |15 |[profile_background_tile, profile_use_background_image]                |[default_profile]|
# |16 |[profile_use_background_image, default_profile]                        |[]               |
# |17 |[profile_use_background_image, default_profile]                        |[]               |
# |18 |[profile_use_background_image, default_profile]                        |[]               |
# |19 |[profile_use_background_image, default_profile]                        |[]               |
# +---+-----------------------------------------------------------------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# <h2 style="color:blue">
# <center>
# Graph: algorithms
# </center>
# </h2>

# %%
from graphframes import *

# %%
# Create edges
e = data_df.select(
    col("user.id").alias("src"),
    col("retweeted_status.user.id").alias("dst"),
    lit("retweet").alias("relationship")
).where(
    col("retweeted_status.user.id").isNotNull()
).distinct()

# %%
# Create vertices
v = data_df.select(
    col("user.id"),
    col("user.screen_name")
).union(
    data_df.select(
        col("retweeted_status.user.id"),
        col("retweeted_status.user.name"),
    ).where(
        col("retweeted_status.user.id").isNotNull()
    )
).distinct()

# %%
# Create graph
g = GraphFrame(v, e)

# %%
# Get top 10 id with highest in degree
g.inDegrees.sort("inDegree", ascending=False).show(10, False)
# Out:
# +-------------------+--------+
# |id                 |inDegree|
# +-------------------+--------+
# |1604444052         |2201    |
# |487297085          |1979    |
# |130496027          |1579    |
# |4196983835         |1359    |
# |1008440487915720708|1319    |
# |16989178           |1110    |
# |19697415           |1070    |
# |150078976          |1056    |
# |2828212668         |984     |
# |3267456386         |930     |
# +-------------------+--------+
# only showing top 10 rows

# %%
# Get top 10 id with lowest in degree
g.inDegrees.sort("inDegree").show(10, False)
# Out:
# +------------------+--------+
# |id                |inDegree|
# +------------------+--------+
# |3358687222        |1       |
# |18611344          |1       |
# |2859622263        |1       |
# |20813564          |1       |
# |179176923         |1       |
# |948171093818343425|1       |
# |540321025         |1       |
# |72954856          |1       |
# |95755482          |1       |
# |135138678         |1       |
# +------------------+--------+
# only showing top 10 rows

# %%
# Get top 10 id with highest out degree
g.outDegrees.sort("outDegree", ascending=False).show(10, False)
# Out:
# +-------------------+---------+
# |id                 |outDegree|
# +-------------------+---------+
# |988374538491777025 |48       |
# |1053011875007483905|24       |
# |824216698551209984 |18       |
# |822210115784806400 |18       |
# |80602426           |17       |
# |2905278738         |16       |
# |62147616           |16       |
# |4053477192         |16       |
# |954454874665771013 |16       |
# |2874358611         |15       |
# +-------------------+---------+
# only showing top 10 rows

# %%
g.edges.show(10, False)
# Out:
# +-------------------+----------+------------+
# |                src|       dst|relationship|
# +-------------------+----------+------------+
# | 828822710478331904|4196983835|     retweet|
# | 798687870240182272| 487297085|     retweet|
# |         2199552860| 112047805|     retweet|
# | 903177352259260419| 460226159|     retweet|
# |          498933814|1398759560|     retweet|
# |          231156352| 111490230|     retweet|
# |1045729609793208320|1604444052|     retweet|
# | 921562006955724800|  49698134|     retweet|
# |          572011574|4429003533|     retweet|
# |         2776139595| 788110982|     retweet|
# |         2448240715| 435207636|     retweet|
# |          437169409|  11856032|     retweet|
# |          774786524|  37824038|     retweet|
# | 933613870756892673|2696243754|     retweet|
# |         3374292849|4196983835|     retweet|
# |1045631048187617280| 593948174|     retweet|
# | 795963986650939392|  14580438|     retweet|
# | 992038732114034690|  20878297|     retweet|
# |           57198714|  42447494|     retweet|
# |           47761597|1339835893|     retweet|
# +-------------------+----------+------------+
# only showing top 20 rows

# %%
# Compute shortest paths from each vertex to the given set of landmark vertices
# For one id with low number of in degree
g.shortestPaths(
    landmarks=["3358687222"]
).select("id", "distances").where(
    size(col("distances")) > 0
).show(10, False)
# Out:
# +------------------+-----------------+
# |id                |distances        |
# +------------------+-----------------+
# |885245073813798912|[3358687222 -> 1]|
# |3358687222        |[3358687222 -> 0]|
# +------------------+-----------------+

# %%
# Compute shortest paths from each vertex to the given set of landmark vertices
# For one id with high number of in degree
g.shortestPaths(
    landmarks=["150078976"]
).select("id", "distances").where(
    size(col("distances")) > 0
).show(10, False)
# Out:
# +------------------+----------------+
# |id                |distances       |
# +------------------+----------------+
# |740005760801726465|[150078976 -> 1]|
# |334776400         |[150078976 -> 1]|
# |849374799868637185|[150078976 -> 1]|
# |935707527580397569|[150078976 -> 1]|
# |3424129696        |[150078976 -> 1]|
# |827544166624325632|[150078976 -> 1]|
# |303950400         |[150078976 -> 1]|
# |498077600         |[150078976 -> 2]|
# |241941600         |[150078976 -> 1]|
# |1566650000        |[150078976 -> 1]|
# +------------------+----------------+
# only showing top 10 rows

# %%
# Computes the number of triangles passing through each vertex
g.triangleCount().select("id", "count").where(col("count") > 0).show(10, False)
# Out:
# +-------------------+-----+
# |id                 |count|
# +-------------------+-----+
# |908149255654854656 |104  |
# |883855148136763392 |4    |
# |883855148136763392 |4    |
# |1003631763133001729|4    |
# |719662077934243840 |12   |
# |197111814          |4    |
# |862106769862078464 |2    |
# |909519301299892225 |40   |
# |909519301299892225 |40   |
# |3100613023         |4    |
# +-------------------+-----+
# only showing top 10 rows
